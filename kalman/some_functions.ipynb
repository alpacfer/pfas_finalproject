# %%
def group_bounding_boxes_per_frame(labels_file, output_file, iou_threshold=0.5):
    """
    Groups overlapping bounding boxes of the same class into a single bounding box per frame.
    Uses one of the track IDs from the grouped set for the resulting bounding box.

    Parameters:
    labels_file (str): Path to the labels.txt file containing bounding box information.
    output_file (str): Path to save the updated labels file with grouped bounding boxes.
    iou_threshold (float): IoU threshold to consider two boxes as overlapping.
    """
    def calculate_iou(box1, box2):
        # Calculate intersection coordinates
        x1_inter = max(box1[0], box2[0])
        y1_inter = max(box1[1], box2[1])
        x2_inter = min(box1[2], box2[2])
        y2_inter = min(box1[3], box2[3])

        # Calculate intersection area
        inter_area = max(0, x2_inter - x1_inter) * max(0, y2_inter - y1_inter)

        # Calculate union area
        box1_area = (box1[2] - box1[0]) * (box1[3] - box1[1])
        box2_area = (box2[2] - box2[0]) * (box2[3] - box2[1])
        union_area = box1_area + box2_area - inter_area

        # Return IoU
        return inter_area / union_area if union_area > 0 else 0

    # Read labels file and extract data
    with open(labels_file, 'r') as file:
        labels = [line.strip().split() for line in file]

    # Group by frame
    frames = {}
    for line in labels:
        frame = int(line[0])
        bbox = list(map(float, line[6:10]))
        obj_data = line[:6] + [bbox] + line[10:]
        if frame not in frames:
            frames[frame] = []
        frames[frame].append(obj_data)

    # Process each frame for grouping
    updated_labels = []
    for frame, objects in frames.items():
        grouped = []
        used = set()

        for i, obj1 in enumerate(objects):
            if i in used:
                continue

            # Start a new group
            group = [obj1]
            used.add(i)

            for j, obj2 in enumerate(objects):
                if j in used or obj1[2] != obj2[2]:  # Skip if already grouped or different class
                    continue

                # Calculate IoU
                bbox1 = obj1[6]
                bbox2 = obj2[6]
                iou = calculate_iou(bbox1, bbox2)

                if iou >= iou_threshold:
                    group.append(obj2)
                    used.add(j)

            grouped.append(group)

        # Merge grouped bounding boxes and update labels
        for group in grouped:
            if len(group) == 1:
                # Single box, no grouping needed
                updated_labels.append(" ".join(map(str, group[0][:6] + group[0][6] + group[0][7:])))
            else:
                # Merge bounding boxes
                min_x = min(obj[6][0] for obj in group)
                min_y = min(obj[6][1] for obj in group)
                max_x = max(obj[6][2] for obj in group)
                max_y = max(obj[6][3] for obj in group)
                merged_bbox = [min_x, min_y, max_x, max_y]

                # Use the first object's data for the new bounding box
                representative = group[0]
                merged_obj = representative[:6] + merged_bbox + representative[10:]
                updated_labels.append(" ".join(map(str, merged_obj)))

    # Write updated labels to output file
    with open(output_file, 'w') as file:
        file.writelines(label + "\n" for label in updated_labels)

    print(f"Grouped bounding boxes saved to {output_file}")

# %%
group_bounding_boxes_per_frame(
    labels_file=r'C:\Users\User\Documents\GitHub\pfas_finalproject\Sequence Labels\Seq_02.txt',
    output_file=r'C:\Users\User\Documents\GitHub\pfas_finalproject\kalman\labels_grouped.txt',
    iou_threshold=0.3  # Specify IoU threshold
)
# Out:
# Grouped bounding boxes saved to C:\Users\User\Documents\GitHub\pfas_finalproject\kalman\labels_grouped.txt

# %% [markdown]
# # Remove range no depth

# %%
def create_labels_with_removed_x_range(labels_file, x_range, new_labels_file):
    """
    Creates a new labels file with track IDs removed if their bounding box falls within a specified x-coordinate range.

    Parameters:
    labels_file (str): Path to the original labels file.
    x_range (tuple): A tuple (x_min, x_max) specifying the range of x-coordinates.
    new_labels_file (str): Path to save the new labels file with track IDs removed.

    Returns:
    None
    """
    x_min, x_max = x_range

    # Read original labels
    with open(labels_file, 'r') as file:
        labels = file.readlines()

    # Prepare modified data
    modified_labels = []
    for line in labels:
        columns = line.strip().split()
        bbox = list(map(float, columns[6:10]))  # Extract bounding box: [left, top, right, bottom]
        left, _, right, _ = bbox

        # Check if the bounding box overlaps with the specified x range
        if x_min <= left <= x_max or x_min <= right <= x_max:
            continue  # Skip this line if the bounding box falls in the x range

        # Add line to modified labels if it doesn't match the exclusion criteria
        modified_labels.append(line)

    # Write modified labels to new file
    with open(new_labels_file, 'w') as file:
        file.writelines(modified_labels)

    print(f"New labels file created: {new_labels_file}")

# %%
create_labels_with_removed_x_range(
    labels_file=r'C:\Users\User\Documents\dataset\pfas\34759_final_project_rect\seq_02\labels.txt',
    x_range=(660, 910),
    new_labels_file=r'C:\Users\User\Documents\GitHub\pfas_finalproject\kalman\artificial_occlusion_better_02.txt'
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 create_labels_with_removed_x_range(
#       2     labels_file=r'C:\Users\User\Documents\dataset\pfas\34759_final_project_rect\seq_02\labels.txt',
#       3     x_range=(660, 910),
#       4     new_labels_file=r'C:\Users\User\Documents\GitHub\pfas_finalproject\kalman\artificial_occlusion_better_02.txt'
#       5 )
#
# NameError: name 'create_labels_with_removed_x_range' is not defined

# %% [markdown]
# # Remove range depth

# %%
def create_labels_with_removed_x_range(labels_file, x_range, new_labels_file):
    """
    Creates a new labels file with track IDs removed if their bounding box falls within a specified x-coordinate range.

    Parameters:
    labels_file (str): Path to the original labels file.
    x_range (tuple): A tuple (x_min, x_max) specifying the range of x-coordinates.
    new_labels_file (str): Path to save the new labels file with track IDs removed.

    Returns:
    None
    """
    x_min, x_max = x_range

    # Read original labels
    with open(labels_file, 'r') as file:
        labels = file.readlines()

    # Prepare modified data
    modified_labels = []
    for line in labels:
        columns = line.strip().split()
        
        # Parse bounding box coordinates
        bbox_left = float(columns[3])  # bbox_left
        bbox_right = float(columns[5])  # bbox_right

        # Check if the bounding box overlaps with the specified x range
        if x_min <= bbox_left <= x_max or x_min <= bbox_right <= x_max:
            continue  # Skip this line if the bounding box falls in the x range

        # Add line to modified labels if it doesn't match the exclusion criteria
        modified_labels.append(line)

    # Write modified labels to new file
    with open(new_labels_file, 'w') as file:
        file.writelines(modified_labels)

    print(f"New labels file created: {new_labels_file}")

# %%
labels_file = r'C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_02.txt'
new_labels_file = r'C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusion_02.txt'
x_range = (660, 910)  # Specify the range of x-coordinates to exclude

create_labels_with_removed_x_range(labels_file, x_range, new_labels_file)
# Out:
# New labels file created: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusion_02.txt

# %%
def visualize_labels_with_classes(labels_file_path, images_folder_path, delay=100):
    """
    Visualizes bounding boxes from YOLO labels with different colors for classes and IDs.

    Args:
        labels_file_path (str): Path to the YOLO labels file.
        images_folder_path (str): Path to the folder containing images.
        delay (int): Time in milliseconds to display each frame. Default is 100 ms.

    Returns:
        None
    """
    import cv2
    import os
    import pandas as pd

    # Define column names for the YOLO labels file
    headers = [
        "frame", "track id", "type", "truncated", "occluded", "alpha",
        "bbox_left", "bbox_top", "bbox_right", "bbox_bottom",
        "dimensions_height", "dimensions_width", "dimensions_length",
        "location_x", "location_y", "location_z",
        "rotation_y", "score"
    ]

    # Load the labels file into a DataFrame
    try:
        df = pd.read_csv(labels_file_path, sep=' ', names=headers)
    except Exception as e:
        print(f"Error reading labels file: {e}")
        return

    # Define a mapping of object types to colors
    classification_colors = {
        "Pedestrian": (34, 139, 34),  # Green
        "Car": (0, 0, 128),           # Navy Blue
        "Cyclist": (139, 0, 0),       # Dark Red
        "misc": (128, 0, 128)         # Purple (default for unclassified objects)
    }

    # Sort frames to process in order
    unique_frames = sorted(df["frame"].unique())

    for frame in unique_frames:

        # Get bounding box data for the current frame
        frame_data = df[df["frame"] == frame]

        # Construct the image path
        image_path = os.path.join(images_folder_path, f"{frame:010d}.png")
        if not os.path.exists(image_path):
            print(f"Image not found: {image_path}")
            continue

        # Read the image
        image = cv2.imread(image_path)
        if image is None:
            print(f"Failed to load image: {image_path}")
            continue

        # Draw bounding boxes on the image
        for _, row in frame_data.iterrows():
            bbox = [row["bbox_left"], row["bbox_top"], row["bbox_right"], row["bbox_bottom"]]
            track_id = row["track id"]
            object_type = row["type"]

            # Determine the color based on the object type
            color = classification_colors.get(object_type, (128, 128, 128))  # Default to gray if type is unknown

            # Draw the bounding box
            cv2.rectangle(
                image,
                (int(bbox[0]), int(bbox[1])),
                (int(bbox[2]), int(bbox[3])),
                color,
                2
            )

            # Add a label for the ID and type
            label = f"ID: {track_id}"
            font = cv2.FONT_HERSHEY_SIMPLEX
            font_scale = 0.5
            font_thickness = 1
            text_size, _ = cv2.getTextSize(label, font, font_scale, font_thickness)
            text_width, text_height = text_size

            # Background rectangle for text
            cv2.rectangle(
                image,
                (int(bbox[0]), int(bbox[1]) - text_height - 5),
                (int(bbox[0]) + text_width, int(bbox[1])),
                (0, 0, 0),  # Black background
                -1
            )
            # Draw the label text
            cv2.putText(
                image,
                label,
                (int(bbox[0]), int(bbox[1]) - 5),
                font,
                font_scale,
                (255, 255, 255),  # White text
                font_thickness
            )

        # Add frame number at the top-left corner
        frame_text = f"Frame: {frame}"
        font = cv2.FONT_HERSHEY_SIMPLEX
        font_scale = 1
        font_thickness = 2
        text_color = (255, 255, 255)  # White text
        bg_color = (0, 0, 0)  # Black background

        # Get text size
        (text_width, text_height), baseline = cv2.getTextSize(frame_text, font, font_scale, font_thickness)

        # Set position for text and background
        text_x = 10
        text_y = 30
        bg_x1 = text_x - 5
        bg_y1 = text_y - text_height - 5
        bg_x2 = text_x + text_width + 5
        bg_y2 = text_y + baseline

        # Draw the background rectangle
        cv2.rectangle(image, (bg_x1, bg_y1), (bg_x2, bg_y2), bg_color, -1)

        # Put the text on top of the background
        cv2.putText(image, frame_text, (text_x, text_y), font, font_scale, text_color, font_thickness)

        # Display the image
        cv2.imshow("YOLO Labels Visualization", image)

        # Wait for the specified delay or exit on 'q' key
        key = cv2.waitKey(delay) & 0xFF
        if key == ord('q'):
            break

    # Close all OpenCV windows
    cv2.destroyAllWindows()

# %%
labels_file_path = r'C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_02.txt'
images_folder_path = r'C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt'

visualize_labels_with_classes(labels_file_path, images_folder_path)
# Out:
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000000.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000001.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000002.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000003.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000004.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000005.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000006.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000007.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000008.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000009.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000010.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000011.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000012.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000013.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000014.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000015.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000016.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000017.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000018.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000019.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000020.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000021.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000022.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000023.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000024.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000025.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000026.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000027.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000028.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000029.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000030.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000031.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000032.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000033.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000034.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000035.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000036.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000037.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000038.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000039.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000040.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000041.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000042.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000043.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000044.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000045.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000046.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000047.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000048.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000049.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000050.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000051.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000052.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000053.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000054.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000055.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000056.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000057.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000058.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000059.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000060.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000061.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000062.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000063.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000064.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000065.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000066.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000067.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000068.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000069.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000070.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000071.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000072.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000073.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000074.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000075.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000076.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000077.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000078.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000079.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000080.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000081.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000082.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000083.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000084.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000085.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000086.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000087.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000088.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000089.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000090.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000091.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000092.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000093.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000094.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000095.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000096.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000097.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000098.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000099.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000100.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000101.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000102.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000103.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000104.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000105.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000106.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000107.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000108.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000109.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000110.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000111.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000112.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000113.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000114.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000115.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000116.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000117.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000118.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000119.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000120.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000121.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000122.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000123.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000124.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000125.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000126.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000127.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000128.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000129.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000130.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000131.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000132.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000133.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000134.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000135.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000136.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000137.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000138.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000139.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000140.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000141.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000142.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000143.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000144.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000145.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000146.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000147.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000148.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000149.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000150.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000151.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000152.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000153.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000154.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000155.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000156.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000157.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000158.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000159.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000160.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000161.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000162.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000163.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000164.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000165.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000166.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000167.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000168.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000169.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000170.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000171.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000172.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000173.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000174.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000175.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000176.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000177.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000178.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000179.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000180.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000181.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000182.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000183.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000184.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000185.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000186.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000187.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000188.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000189.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000190.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000191.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000192.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000193.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000194.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000195.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000196.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000197.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000198.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000199.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000200.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000201.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000202.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000203.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000204.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000205.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000206.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000207.png
# Image not found: C:\Users\User\Documents\GitHub\pfas_finalproject\kalman_3d\depth_fixed_occlusions_02.txt\0000000208.png

# %%
def filter_short_lived_consecutive_track_ids(labels_file, output_file, min_consecutive_frames=10):
    """
    Filters out track IDs that appear in fewer consecutive frames than the specified threshold.

    Parameters:
    labels_file (str): Path to the input labels.txt file.
    output_file (str): Path to save the filtered labels file.
    min_consecutive_frames (int): Minimum number of consecutive frames a track ID must appear in to be retained.

    Returns:
    None
    """
    import pandas as pd

    # Define column names for the labels file
    headers = [
        "frame", "track_id", "type", "truncated", "occluded", "alpha",
        "bbox_left", "bbox_top", "bbox_right", "bbox_bottom",
        "dimensions_height", "dimensions_width", "dimensions_length",
        "location_x", "location_y", "location_z",
        "rotation_y", "score"
    ]

    # Read the labels file into a DataFrame
    try:
        df = pd.read_csv(labels_file, sep=' ', names=headers)
    except Exception as e:
        print(f"Error reading labels file: {e}")
        return

    # Function to find maximum consecutive frames for a track
    def max_consecutive_frames(frames):
        if len(frames) < min_consecutive_frames:
            return 0
        
        # Sort frames
        sorted_frames = sorted(frames)
        
        # Track consecutive frames
        max_consecutive = 1
        current_consecutive = 1
        
        for i in range(1, len(sorted_frames)):
            if sorted_frames[i] == sorted_frames[i-1] + 1:
                current_consecutive += 1
                max_consecutive = max(max_consecutive, current_consecutive)
            else:
                current_consecutive = 1
        
        return max_consecutive

    # Group by track ID and find consecutive frames
    track_consecutive_frames = df.groupby("track_id")["frame"].apply(max_consecutive_frames)
    
    # Get valid track IDs (those with sufficient consecutive frames)
    valid_track_ids = track_consecutive_frames[track_consecutive_frames >= min_consecutive_frames].index.tolist()

    # Filter the DataFrame to include only valid track IDs
    filtered_df = df[df["track_id"].isin(valid_track_ids)]

    # Save the filtered DataFrame to the output file
    try:
        filtered_df.to_csv(output_file, sep=' ', index=False, header=False)
        
        # Print some statistics
        total_tracks = len(df["track_id"].unique())
        filtered_tracks = len(filtered_df["track_id"].unique())
        print(f"Total unique track IDs: {total_tracks}")
        print(f"Filtered track IDs (with at least {min_consecutive_frames} consecutive frames): {filtered_tracks}")
        print(f"Filtered labels saved to {output_file}")
    except Exception as e:
        print(f"Error writing filtered labels file: {e}")

# %%
labels_file = r'C:\Users\User\Documents\GitHub\pfas_finalproject\Sequence Labels\Seq_03.txt'
output_file = r'C:\Users\User\Documents\GitHub\pfas_finalproject\kalman\filtered_labels_03.txt'

images_folder_path = r'C:\Users\User\Documents\dataset\pfas\34759_final_project_rect\seq_03\image_02\data'

filter_short_lived_consecutive_track_ids(labels_file, output_file, min_consecutive_frames=15)

# Visualize the filtered labels
visualize_labels_with_classes(output_file, images_folder_path)
# Out:
# Total unique track IDs: 33
# Filtered track IDs (with at least 15 consecutive frames): 18
# Filtered labels saved to C:\Users\User\Documents\GitHub\pfas_finalproject\kalman\filtered_labels_03.txt

# %% [markdown]
# # Fix depth
